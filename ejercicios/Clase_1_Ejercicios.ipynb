# %% [markdown]
# <a href="https://colab.research.google.com/github/sanrodmu29/Curso_Programacion_Cientifica/blob/main/ejercicios/Clase_1_Ejercicios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EJERCICIOS

# %%
print("Hola Mundo")
# Out:
# Hola Mundo
